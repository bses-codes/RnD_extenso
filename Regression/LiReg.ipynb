# %%
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression
import matplotlib.pyplot as plt

# %%
x = np.arange(100).reshape(-1,1)
delta = np.random.uniform(-10,10, size=(100,))
y = .4 * x.flatten() -3  + delta

# %%
plt.scatter(x.flatten(), y)

# %%
LiReg = LinearRegression()
LiReg.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x.flatten(), y, color='blue')
plt.plot(x.flatten(), LiReg.predict(x), color='red')
plt.show()

# %%
x = np.random.normal(0, 1, 100).reshape(-1, 1) 
y = (x[:, 0] > 0.5).astype(int)

# %%
plt.scatter(x, y)

# %%
LoReg = LogisticRegression()
LoReg.fit(X, y)
# Out:
# LogisticRegression()

# %%
X_test = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
y_prob = LoReg.predict_proba(X_test)[:, 1] 
plt.scatter(X.flatten(), y)
plt.plot(X_test, y_prob, color='red', linewidth=3)
plt.show()
