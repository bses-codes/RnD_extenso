# %%
import mysql.connector as connection
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
conn = connection.connect(
    host="Bisheshs-MacBook-Pro.local", 
    database = 'assign',
    user='root', 
    password='12345678')

# %%
query = "Select * from rw_transaction_data"
rw_transaction_data = pd.read_sql(query,conn)
# Out:
# /var/folders/nk/tzs157bs2zl7cfxbfgzc6n_h0000gn/T/ipykernel_11980/3252396739.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rw_transaction_data = pd.read_sql(query,conn)

# %%
rw_transaction_data
# Out:
#           txn_id last_modified_date last_modified_date_bs created_date  \
# 0      660612529         2023-03-29            2079-12-15   2022-11-23
# 1      666435422         2022-12-01            2079-08-15   2022-12-01
# 2      666436001         2022-12-01            2079-08-15   2022-12-01
# 3      666436068         2022-12-01            2079-08-15   2022-12-01
# 4      666437220         2022-12-01            2079-08-15   2022-12-01
# ...          ...                ...                   ...          ...
# 11007  693909708         2023-01-06            2079-09-22   2023-01-06
# 11008  693909889         2023-01-06            2079-09-22   2023-01-06
# 11009  693909963         2023-01-06            2079-09-22   2023-01-06
# 11010  693909991         2023-01-06            2079-09-22   2023-01-06
# 11011  693909995         2023-01-06            2079-09-22   2023-01-06
#
#        amount  status  module_id  product_id  product_type_id  \
# 0        50.0       1          1          77               29
# 1       750.0       1          1          76               29
# 2        50.0       1          1          77               29
# 3        50.0       1          1          77               29
# 4       100.0       1          1          30               29
# ...       ...     ...        ...         ...              ...
# 11007   260.0       1          1          30               29
# 11008    50.0       1          1          30               29
# 11009    10.0       1          1          30               29
# 11010    50.0       1          1          30               29
# 11011  1576.0       1          1         132               29
#
#        payer_account_id  receiver_account_id  reward_point  cash_back_amount  \
# 0                   531                    2           0.0              0.00
# 1                   531                   81           0.0              0.00
# 2                   531                    2           0.0              1.38
# 3                   531                  647           0.0              1.38
# 4                   531                  907           0.0              3.90
# ...                 ...                  ...           ...               ...
# 11007               531                  907           0.0             10.14
# 11008               531                  176           0.0              1.95
# 11009               531                  645           0.0              0.39
# 11010               531                  907           0.0              1.95
# 11011               531                  423           0.0              0.00
#
#        revenue_amount  transactor_module_id      time
# 0                0.00                     4  14:07:40
# 1               33.75                     4  00:03:41
# 2                0.00                     4  00:06:20
# 3                0.00                     4  00:06:32
# 4                0.00                     4  00:12:51
# ...               ...                   ...       ...
# 11007            0.00                     4  11:37:36
# 11008            0.00                     4  11:37:48
# 11009            0.00                     4  11:37:52
# 11010            0.00                     4  11:37:54
# 11011            0.00                     4  11:37:54
#
# [11012 rows x 16 columns]

# %%
query = "Select * from  product_category_map"
product_category_map = pd.read_sql(query,conn)
# Out:
# /var/folders/nk/tzs157bs2zl7cfxbfgzc6n_h0000gn/T/ipykernel_11980/1267947249.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_category_map = pd.read_sql(query,conn)

# %%
query = "Select * from product_category"
product_category = pd.read_sql(query,conn)
# Out:
# /var/folders/nk/tzs157bs2zl7cfxbfgzc6n_h0000gn/T/ipykernel_11980/1510399642.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_category = pd.read_sql(query,conn)

# %%
query = "Select * from customer_profile"
customer_profile = pd.read_sql(query,conn)
# Out:
# /var/folders/nk/tzs157bs2zl7cfxbfgzc6n_h0000gn/T/ipykernel_11980/338470190.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   customer_profile = pd.read_sql(query,conn)
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/F1_Intern/Customer_Profile/.venv/lib/python3.12/site-packages/mysql/connector/connection_cext.py:697, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     696         query = query.encode("utf-8")
# --> 697     self._cmysql.query(
#     698         query,
#     699         raw=raw,
#     700         buffered=buffered,
#     701         raw_as_string=raw_as_string,
#     702         query_attrs=self.query_attrs,
#     703     )
#     704 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'assign.customer_profile' doesn't exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# File ~/F1_Intern/Customer_Profile/.venv/lib/python3.12/site-packages/pandas/io/sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# File ~/F1_Intern/Customer_Profile/.venv/lib/python3.12/site-packages/mysql/connector/cursor_cext.py:372, in CMySQLCursor.execute(self, operation, params, multi)
#     371 try:
# --> 372     result = self._cnx.cmd_query(
#     373         stmt,
#     374         raw=self._raw,
#     375         buffered=self._buffered,
#     376         raw_as_string=self._raw_as_string,
#     377     )
#     378 except MySQLInterfaceError as err:
#
# File ~/F1_Intern/Customer_Profile/.venv/lib/python3.12/site-packages/mysql/connector/opentelemetry/context_propagation.py:102, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#     101 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# --> 102     return method(cnx, *args, **kwargs)
#     104 current_span = trace.get_current_span()
#
# File ~/F1_Intern/Customer_Profile/.venv/lib/python3.12/site-packages/mysql/connector/connection_cext.py:705, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     704 except MySQLInterfaceError as err:
# --> 705     raise get_mysql_exception(
#     706         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     707     ) from err
#     708 except AttributeError as err:
#
# ProgrammingError: 1146 (42S02): Table 'assign.customer_profile' doesn't exist
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[7], line 2
#       1 query = "Select * from customer_profile"
# ----> 2 customer_profile = pd.read_sql(query,conn)
#
# File ~/F1_Intern/Customer_Profile/.venv/lib/python3.12/site-packages/pandas/io/sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
# --> 706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#     709             params=params,
#     710             coerce_float=coerce_float,
#     711             parse_dates=parse_dates,
#     712             chunksize=chunksize,
#     713             dtype_backend=dtype_backend,
#     714             dtype=dtype,
#     715         )
#     717     try:
#     718         _is_table_name = pandas_sql.has_table(sql)
#
# File ~/F1_Intern/Customer_Profile/.venv/lib/python3.12/site-packages/pandas/io/sql.py:2738, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2727 def read_query(
#    2728     self,
#    2729     sql,
#    (...)
#    2736     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737 ) -> DataFrame | Iterator[DataFrame]:
# -> 2738     cursor = self.execute(sql, params)
#    2739     columns = [col_desc[0] for col_desc in cursor.description]
#    2741     if chunksize is not None:
#
# File ~/F1_Intern/Customer_Profile/.venv/lib/python3.12/site-packages/pandas/io/sql.py:2686, in SQLiteDatabase.execute(self, sql, params)
#    2683     raise ex from inner_exc
#    2685 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686 raise ex from exc
#
# DatabaseError: Execution failed on sql 'Select * from customer_profile': 1146 (42S02): Table 'assign.customer_profile' doesn't exist

# %%
query = "Select * from products"
products = pd.read_sql(query,conn)
# Out:
# /var/folders/nk/tzs157bs2zl7cfxbfgzc6n_h0000gn/T/ipykernel_11980/2478507768.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   products = pd.read_sql(query,conn)

# %%
rw_transaction_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11012 entries, 0 to 11011
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   txn_id                 11012 non-null  int64
#  1   last_modified_date     11012 non-null  object
#  2   last_modified_date_bs  11012 non-null  object
#  3   created_date           11012 non-null  object
#  4   amount                 11012 non-null  float64
#  5   status                 11012 non-null  int64
#  6   module_id              11012 non-null  int64
#  7   product_id             11012 non-null  int64
#  8   product_type_id        11012 non-null  int64
#  9   payer_account_id       11012 non-null  int64
#  10  receiver_account_id    11012 non-null  int64
#  11  reward_point           11012 non-null  float64
#  12  cash_back_amount       11012 non-null  float64
#  13  revenue_amount         11012 non-null  float64
#  14  transactor_module_id   11012 non-null  int64
#  15  time                   11012 non-null  object
# dtypes: float64(4), int64(8), object(4)
# memory usage: 1.3+ MB

# %%
rw_transaction_data.isna().sum()
# Out:
# txn_id                   0
# last_modified_date       0
# last_modified_date_bs    0
# created_date             0
# amount                   0
# status                   0
# module_id                0
# product_id               0
# product_type_id          0
# payer_account_id         0
# receiver_account_id      0
# reward_point             0
# cash_back_amount         0
# revenue_amount           0
# transactor_module_id     0
# time                     0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=rw_transaction_data['amount'])
plt.title('Boxplot of Amount')
plt.xlabel('Amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=rw_transaction_data['cash_back_amount'])
plt.title('Boxplot of Cashback Amount')
plt.xlabel('Cashback Amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=rw_transaction_data['revenue_amount'])
plt.title('Boxplot of Revenue Amount')
plt.xlabel('Revenue Amount')
plt.show()

# %%
merged_df = pd.merge(rw_transaction_data, product_category_map, on=['module_id', 'product_id', 'product_type_id'], how='inner')

# %%
merged_df
# Out:
#           txn_id last_modified_date last_modified_date_bs created_date  \
# 0      660612529         2023-03-29            2079-12-15   2022-11-23
# 1      660612529         2023-03-29            2079-12-15   2022-11-23
# 2      666435422         2022-12-01            2079-08-15   2022-12-01
# 3      666436001         2022-12-01            2079-08-15   2022-12-01
# 4      666436001         2022-12-01            2079-08-15   2022-12-01
# ...          ...                ...                   ...          ...
# 10775  693909439         2023-01-06            2079-09-22   2023-01-06
# 10776  693909708         2023-01-06            2079-09-22   2023-01-06
# 10777  693909889         2023-01-06            2079-09-22   2023-01-06
# 10778  693909963         2023-01-06            2079-09-22   2023-01-06
# 10779  693909991         2023-01-06            2079-09-22   2023-01-06
#
#        amount  status  module_id  product_id  product_type_id  \
# 0        50.0       1          1          77               29
# 1        50.0       1          1          77               29
# 2       750.0       1          1          76               29
# 3        50.0       1          1          77               29
# 4        50.0       1          1          77               29
# ...       ...     ...        ...         ...              ...
# 10775   100.0       1          1          30               29
# 10776   260.0       1          1          30               29
# 10777    50.0       1          1          30               29
# 10778    10.0       1          1          30               29
# 10779    50.0       1          1          30               29
#
#        payer_account_id  receiver_account_id  reward_point  cash_back_amount  \
# 0                   531                    2           0.0              0.00
# 1                   531                    2           0.0              0.00
# 2                   531                   81           0.0              0.00
# 3                   531                    2           0.0              1.38
# 4                   531                    2           0.0              1.38
# ...                 ...                  ...           ...               ...
# 10775               531                  176           0.0              3.90
# 10776               531                  907           0.0             10.14
# 10777               531                  176           0.0              1.95
# 10778               531                  645           0.0              0.39
# 10779               531                  907           0.0              1.95
#
#        revenue_amount  transactor_module_id      time           product_name  \
# 0                0.00                     4  14:07:40  TOPUP VIA BANK DIRECT
# 1                0.00                     4  14:07:40   Ncell Topup via Bank
# 2               33.75                     4  00:03:41  SIM TV TOPUP VIA BANK
# 3                0.00                     4  00:06:20  TOPUP VIA BANK DIRECT
# 4                0.00                     4  00:06:20   Ncell Topup via Bank
# ...               ...                   ...       ...                    ...
# 10775            0.00                     4  11:37:20      NT Topup via Bank
# 10776            0.00                     4  11:37:36      NT Topup via Bank
# 10777            0.00                     4  11:37:48      NT Topup via Bank
# 10778            0.00                     4  11:37:52      NT Topup via Bank
# 10779            0.00                     4  11:37:54      NT Topup via Bank
#
#        product_category_id     txn_flow
# 0                      NaN  Value Chain
# 1                     14.0  Value Chain
# 2                     21.0  Value Chain
# 3                      NaN  Value Chain
# 4                     14.0  Value Chain
# ...                    ...          ...
# 10775                 14.0  Value Chain
# 10776                 14.0  Value Chain
# 10777                 14.0  Value Chain
# 10778                 14.0  Value Chain
# 10779                 14.0  Value Chain
#
# [10780 rows x 19 columns]

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='txn_flow', data=merged_df)
plt.title('Frequency of Transaction flow')
plt.xlabel('Transaction flow')
plt.ylabel('Count')
plt.show()

# %%
merged_df['last_modified_date'] = pd.to_datetime(merged_df['last_modified_date'])
merged_df['month'] = merged_df['last_modified_date'].dt.month
grouped_data = merged_df.groupby(['payer_account_id', 'month', 'txn_flow'])
sum_amount_by_month = grouped_data['amount'].sum()

# %%
sum_amount_by_month
# Out:
# payer_account_id  month  txn_flow
# 26                1      InFlow           34340.0
#                          OutFlow          51340.0
#                          Value Chain      18011.0
#                   12     Value Chain        460.0
# 34                1      InFlow         2133150.0
#                          OutFlow        2396770.0
#                          Value Chain     246737.0
#                   12     InFlow           83200.0
#                          OutFlow          88200.0
#                          Value Chain       4351.0
# 56                1      InFlow           15750.0
#                          OutFlow         135750.0
#                          Value Chain      68204.0
#                   12     InFlow            9725.0
#                          OutFlow          12125.0
#                          Value Chain      18301.0
# 222               1      Value Chain        240.0
#                   12     Value Chain        270.0
# 471               1      InFlow             700.0
#                          OutFlow            700.0
#                          Value Chain      18850.0
#                   12     Value Chain       3048.0
# 531               1      Value Chain    1275093.0
#                   3      Value Chain        100.0
#                   12     Value Chain     600054.0
# 1056              12     Value Chain        400.0
# Name: amount, dtype: float64

# %%
merged_df['last_modified_date'] = pd.to_datetime(merged_df['last_modified_date'])
merged_df['week'] = merged_df['last_modified_date'].dt.isocalendar().week
grouped_data = merged_df.groupby(['payer_account_id','product_category_id', 'week'])
sum_amount_by_week = grouped_data['amount'].sum()

# %%
sum_amount_by_week
# Out:
# payer_account_id  product_category_id  week
# 26                14.0                 1         1200.0
#                                        48         280.0
#                                        52        3200.0
#                   19.0                 1         4911.0
#                   90.0                 1        46200.0
#                                                  ...
# 531               21.0                 48         750.0
#                   75.0                 1       172550.0
#                                        48       95797.0
#                                        52        1850.0
# 1056              14.0                 48         200.0
# Name: amount, Length: 65, dtype: float64

# %%
final_df = merged_df.groupby('payer_account_id')['reward_point'].sum()
final_df
# Out:
# payer_account_id
# 26       0.0
# 34      68.0
# 56      39.0
# 222      0.0
# 471     14.0
# 531      0.0
# 1056     8.0
# Name: reward_point, dtype: float64

# %%
pivot_table = merged_df.pivot_table(index='payer_account_id', columns='txn_flow', values='amount', aggfunc='sum')
pivot_table.reset_index(inplace=True)
pivot_table.fillna(0, inplace=True)
pivot_table.columns = ['payer_account_id', 'Total InFlow Amount', 'Total OutFlow Amount','Total Valuechain Amount']
df1 = pd.DataFrame(pivot_table)
df1
# Out:
#    payer_account_id  Total InFlow Amount  Total OutFlow Amount  \
# 0                26              34340.0               51340.0
# 1                34            2216350.0             2484970.0
# 2                56              25475.0              147875.0
# 3               222                  0.0                   0.0
# 4               471                700.0                 700.0
# 5               531                  0.0                   0.0
# 6              1056                  0.0                   0.0
#
#    Total Valuechain Amount
# 0                  18471.0
# 1                 251088.0
# 2                  86505.0
# 3                    510.0
# 4                  21898.0
# 5                1875247.0
# 6                    400.0

# %%
final_df = pd.merge(final_df,df1,on='payer_account_id')

# %%
# Create a pivot table to aggregate 'amount' based on 'txn_flow'
pivot_table1 = merged_df.pivot_table(index='payer_account_id', columns='txn_flow', values='amount', aggfunc='count')

# Reset index to make 'payer_account_id' a regular column
pivot_table1.reset_index(inplace=True)

# Fill NaN values with 0
pivot_table1.fillna(0, inplace=True)
pivot_table1.columns = ['payer_account_id', 'Total InFlow Count', 'Total OutFlow Count','Total Valuechain Count']
final_df = pd.merge(final_df,pd.DataFrame(pivot_table1),on='payer_account_id')

# %%
final_df
# Out:
#    payer_account_id  reward_point  Total InFlow Amount  Total OutFlow Amount  \
# 0                26           0.0              34340.0               51340.0
# 1                34          68.0            2216350.0             2484970.0
# 2                56          39.0              25475.0              147875.0
# 3               222           0.0                  0.0                   0.0
# 4               471          14.0                700.0                 700.0
# 5               531           0.0                  0.0                   0.0
# 6              1056           8.0                  0.0                   0.0
#
#    Total Valuechain Amount  Total InFlow Count  Total OutFlow Count  \
# 0                  18471.0                12.0                 15.0
# 1                 251088.0               126.0                143.0
# 2                  86505.0                15.0                 22.0
# 3                    510.0                 0.0                  0.0
# 4                  21898.0                 2.0                  2.0
# 5                1875247.0                 0.0                  0.0
# 6                    400.0                 0.0                  0.0
#
#    Total Valuechain Count
# 0                    53.0
# 1                    80.0
# 2                   193.0
# 3                     4.0
# 4                   116.0
# 5                  9995.0
# 6                     2.0

# %%
# merged_df['last_modified_date'] = pd.to_datetime(merged_df['last_modified_date'])
# merged_df['month'] = merged_df['last_modified_date'].dt.month
# grouped_data = merged_df.groupby(['payer_account_id', 'month'])
# sum_amount_by_month = grouped_data['amount'].sum()
# sum_amount_by_month
# Out:
# payer_account_id  month
# 26                1         103691.0
#                   12           460.0
# 34                1        4776657.0
#                   12        175751.0
# 56                1         219704.0
#                   12         40151.0
# 222               1            240.0
#                   12           270.0
# 471               1          20250.0
#                   12          3048.0
# 531               1        1275093.0
#                   3            100.0
#                   12        600054.0
# 1056              12           400.0
# Name: amount, dtype: float64

# %%
df = pd.DataFrame(sum_amount_by_month)
pivot_table = df.pivot_table(index='payer_account_id', columns='txn_flow', values='amount', aggfunc='mean')
pivot_table.reset_index(inplace=True)
pivot_table.fillna(0, inplace=True)
pivot_table.columns = ['payer_account_id','monthly_inflow_amount', 'monthly_outflow_amount', 'monthly_valuechain_amount']
df1 = pd.DataFrame(pivot_table)
final_df = pd.merge(final_df,df1,on='payer_account_id')

# %%
final_df
# Out:
#    payer_account_id  reward_point  Total InFlow Amount  Total OutFlow Amount  \
# 0                26           0.0              34340.0               51340.0
# 1                34          68.0            2216350.0             2484970.0
# 2                56          39.0              25475.0              147875.0
# 3               222           0.0                  0.0                   0.0
# 4               471          14.0                700.0                 700.0
# 5               531           0.0                  0.0                   0.0
# 6              1056           8.0                  0.0                   0.0
#
#    Total Valuechain Amount  Total InFlow Count  Total OutFlow Count  \
# 0                  18471.0                12.0                 15.0
# 1                 251088.0               126.0                143.0
# 2                  86505.0                15.0                 22.0
# 3                    510.0                 0.0                  0.0
# 4                  21898.0                 2.0                  2.0
# 5                1875247.0                 0.0                  0.0
# 6                    400.0                 0.0                  0.0
#
#    Total Valuechain Count  monthly_inflow_amount  monthly_outflow_amount  \
# 0                    53.0                34340.0                 51340.0
# 1                    80.0              1108175.0               1242485.0
# 2                   193.0                12737.5                 73937.5
# 3                     4.0                    0.0                     0.0
# 4                   116.0                  700.0                   700.0
# 5                  9995.0                    0.0                     0.0
# 6                     2.0                    0.0                     0.0
#
#    monthly_valuechain_amount
# 0                9235.500000
# 1              125544.000000
# 2               43252.500000
# 3                 255.000000
# 4               10949.000000
# 5              625082.333333
# 6                 400.000000

# %%
# pivot_table1 = df.pivot_table(index='payer_account_id', columns='txn_flow', values='amount', aggfunc='count')
# pivot_table1.reset_index(inplace=True)
# pivot_table1.fillna(0, inplace=True)
# pivot_table1
# Out:
# txn_flow  payer_account_id  InFlow  OutFlow  Value Chain
# 0                       26     1.0      1.0          2.0
# 1                       34     2.0      2.0          2.0
# 2                       56     2.0      2.0          2.0
# 3                      222     0.0      0.0          2.0
# 4                      471     1.0      1.0          2.0
# 5                      531     0.0      0.0          3.0
# 6                     1056     0.0      0.0          1.0

# %%
# count_per_month = df.groupby(['payer_account_id', 'month', 'txn_flow'])['amount'].count().reset_index()
# count_per_month = count_per_month.rename(columns={'amount': 'amount_count'})
# count_per_month.groupby(['payer_account_id','txn_flow'])['amount_count'].count()
# pivot_table2 = count_per_month.pivot_table(index='payer_account_id', columns='txn_flow', values='amount_count', aggfunc='mean')
# pivot_table2.reset_index(inplace=True)
# pivot_table2.fillna(0, inplace=True)
# final_df = pd.merge(final_df, pd.DataFrame(pivot_table2), on='payer_account_id')
# final_df

# Create pivot table with counts of transactions
count_pivot_table = pd.pivot_table(merged_df, values='amount', index=['payer_account_id', 'month'], columns='txn_flow', aggfunc='count')

# Calculate average inflow, outflow, and value chain
average_per_account = count_pivot_table.groupby('payer_account_id').mean()

# Rename columns for clarity
average_per_account.rename(columns={'InFlow': 'Average InFlow', 'OutFlow': 'Average OutFlow', 'ValueChain': 'Average ValueChain'}, inplace=True)

data = pd.DataFrame(average_per_account)
final_df = pd.merge(final_df,data,on='payer_account_id')

# %%
data
# Out:
# txn_flow          Average InFlow  Average OutFlow  Value Chain
# payer_account_id
# 26                          12.0             15.0    26.500000
# 34                          63.0             71.5    40.000000
# 56                           7.5             11.0    96.500000
# 222                          NaN              NaN     2.000000
# 471                          2.0              2.0    58.000000
# 531                          NaN              NaN  3331.666667
# 1056                         NaN              NaN     2.000000

# %%
final_df
# Out:
#    payer_account_id  reward_point  Total InFlow Amount  Total OutFlow Amount  \
# 0                26           0.0              34340.0               51340.0
# 1                34          68.0            2216350.0             2484970.0
# 2                56          39.0              25475.0              147875.0
# 3               222           0.0                  0.0                   0.0
# 4               471          14.0                700.0                 700.0
# 5               531           0.0                  0.0                   0.0
# 6              1056           8.0                  0.0                   0.0
#
#    Total Valuechain Amount  Total InFlow Count  Total OutFlow Count  \
# 0                  18471.0                12.0                 15.0
# 1                 251088.0               126.0                143.0
# 2                  86505.0                15.0                 22.0
# 3                    510.0                 0.0                  0.0
# 4                  21898.0                 2.0                  2.0
# 5                1875247.0                 0.0                  0.0
# 6                    400.0                 0.0                  0.0
#
#    Total Valuechain Count  monthly_inflow_amount  monthly_outflow_amount  \
# 0                    53.0                34340.0                 51340.0
# 1                    80.0              1108175.0               1242485.0
# 2                   193.0                12737.5                 73937.5
# 3                     4.0                    0.0                     0.0
# 4                   116.0                  700.0                   700.0
# 5                  9995.0                    0.0                     0.0
# 6                     2.0                    0.0                     0.0
#
#    monthly_valuechain_amount  Average InFlow  Average OutFlow  Value Chain
# 0                9235.500000            12.0             15.0    26.500000
# 1              125544.000000            63.0             71.5    40.000000
# 2               43252.500000             7.5             11.0    96.500000
# 3                 255.000000             NaN              NaN     2.000000
# 4               10949.000000             2.0              2.0    58.000000
# 5              625082.333333             NaN              NaN  3331.666667
# 6                 400.000000             NaN              NaN     2.000000

# %%
sorted_df = merged_df.sort_values(by=['last_modified_date', 'time'], ascending=False)
latest_product_per_account = sorted_df.groupby('payer_account_id').first()
latest_product_per_account = latest_product_per_account[['product_name', 'last_modified_date']]
latest_product_per_account.reset_index(inplace=True)
df3 = pd.DataFrame(latest_product_per_account)
df3.columns = ['payer_account_id','latest_product_used','latest_tran_date']
final_df = pd.merge(final_df,df3,on='payer_account_id')
final_df
# Out:
#    payer_account_id  reward_point  Total InFlow Amount  Total OutFlow Amount  \
# 0                26           0.0              34340.0               51340.0
# 1                34          68.0            2216350.0             2484970.0
# 2                56          39.0              25475.0              147875.0
# 3               222           0.0                  0.0                   0.0
# 4               471          14.0                700.0                 700.0
# 5               531           0.0                  0.0                   0.0
# 6              1056           8.0                  0.0                   0.0
#
#    Total Valuechain Amount  Total InFlow Count  Total OutFlow Count  \
# 0                  18471.0                12.0                 15.0
# 1                 251088.0               126.0                143.0
# 2                  86505.0                15.0                 22.0
# 3                    510.0                 0.0                  0.0
# 4                  21898.0                 2.0                  2.0
# 5                1875247.0                 0.0                  0.0
# 6                    400.0                 0.0                  0.0
#
#    Total Valuechain Count  monthly_inflow_amount  monthly_outflow_amount  \
# 0                    53.0                34340.0                 51340.0
# 1                    80.0              1108175.0               1242485.0
# 2                   193.0                12737.5                 73937.5
# 3                     4.0                    0.0                     0.0
# 4                   116.0                  700.0                   700.0
# 5                  9995.0                    0.0                     0.0
# 6                     2.0                    0.0                     0.0
#
#    monthly_valuechain_amount  Average InFlow  Average OutFlow  Value Chain  \
# 0                9235.500000            12.0             15.0    26.500000
# 1              125544.000000            63.0             71.5    40.000000
# 2               43252.500000             7.5             11.0    96.500000
# 3                 255.000000             NaN              NaN     2.000000
# 4               10949.000000             2.0              2.0    58.000000
# 5              625082.333333             NaN              NaN  3331.666667
# 6                 400.000000             NaN              NaN     2.000000
#
#      latest_product_used latest_tran_date
# 0          Prepaid Topup       2023-01-06
# 1            Electricity       2023-01-06
# 2            Electricity       2023-01-06
# 3            Ncell Topup       2023-01-01
# 4          Prepaid Topup       2023-01-06
# 5  TOPUP VIA BANK DIRECT       2023-03-29
# 6          Prepaid Topup       2022-12-01

# %%
merged_df['last_modified_date'] = pd.to_datetime(merged_df['last_modified_date'])
merged_df['month'] = merged_df['last_modified_date'].dt.month
monthly_revenue = merged_df.groupby(['payer_account_id', 'month'])['revenue_amount'].sum()
average_monthly_revenue_per_account = monthly_revenue.groupby('payer_account_id').mean()
df4 = pd.DataFrame(average_monthly_revenue_per_account)
df4.columns = ['monthly_average_lifetime_revenue']
final_df = pd.merge(final_df,df4,on='payer_account_id')

# %%
final_df
# Out:
#    payer_account_id  reward_point  Total InFlow Amount  Total OutFlow Amount  \
# 0                26           0.0              34340.0               51340.0
# 1                34          68.0            2216350.0             2484970.0
# 2                56          39.0              25475.0              147875.0
# 3               222           0.0                  0.0                   0.0
# 4               471          14.0                700.0                 700.0
# 5               531           0.0                  0.0                   0.0
# 6              1056           8.0                  0.0                   0.0
#
#    Total Valuechain Amount  Total InFlow Count  Total OutFlow Count  \
# 0                  18471.0                12.0                 15.0
# 1                 251088.0               126.0                143.0
# 2                  86505.0                15.0                 22.0
# 3                    510.0                 0.0                  0.0
# 4                  21898.0                 2.0                  2.0
# 5                1875247.0                 0.0                  0.0
# 6                    400.0                 0.0                  0.0
#
#    Total Valuechain Count  monthly_inflow_amount  monthly_outflow_amount  \
# 0                    53.0                34340.0                 51340.0
# 1                    80.0              1108175.0               1242485.0
# 2                   193.0                12737.5                 73937.5
# 3                     4.0                    0.0                     0.0
# 4                   116.0                  700.0                   700.0
# 5                  9995.0                    0.0                     0.0
# 6                     2.0                    0.0                     0.0
#
#    monthly_valuechain_amount  Average InFlow  Average OutFlow  Value Chain  \
# 0                9235.500000            12.0             15.0    26.500000
# 1              125544.000000            63.0             71.5    40.000000
# 2               43252.500000             7.5             11.0    96.500000
# 3                 255.000000             NaN              NaN     2.000000
# 4               10949.000000             2.0              2.0    58.000000
# 5              625082.333333             NaN              NaN  3331.666667
# 6                 400.000000             NaN              NaN     2.000000
#
#      latest_product_used latest_tran_date  monthly_average_lifetime_revenue
# 0          Prepaid Topup       2023-01-06                         20.430000
# 1            Electricity       2023-01-06                        258.215000
# 2            Electricity       2023-01-06                        101.055000
# 3            Ncell Topup       2023-01-01                          1.910000
# 4          Prepaid Topup       2023-01-06                         49.890000
# 5  TOPUP VIA BANK DIRECT       2023-03-29                        758.013333
# 6          Prepaid Topup       2022-12-01                         14.000000

# %%
df6 = merged_df.groupby('payer_account_id')['revenue_amount'].sum()

# %%
df6.columns = ['total_revenue']
final_df = pd.merge(final_df,df6,on='payer_account_id')

# %%
df7 = merged_df.groupby('payer_account_id')['product_name'].nunique()
df7 = pd.DataFrame(df7).reset_index()
df7.columns = ['payer_account_id', 'product_usage']
final_df = pd.merge(final_df,df7,on='payer_account_id')

# %%
product_counts = merged_df.groupby(['payer_account_id', 'product_name']).size().reset_index(name='count')
product_counts_sorted = product_counts.sort_values(by=['payer_account_id', 'count'], ascending=[True, False])
top_three_products = product_counts_sorted.groupby('payer_account_id').head(3)

# %%
pivot_df = top_three_products.pivot_table(index='payer_account_id', columns=top_three_products.groupby('payer_account_id').cumcount() + 1, values='product_name', aggfunc='first')
pivot_df.columns = ['most_used_product', 'second_most_used_product', 'thirdmost_used_product']
pivot_df.reset_index(inplace=True)
df8 = pd.DataFrame(pivot_df)
final_df = pd.merge(final_df,df8,on='payer_account_id')

# %%
final_df
# Out:
#    payer_account_id  reward_point  Total InFlow Amount  Total OutFlow Amount  \
# 0                26           0.0              34340.0               51340.0
# 1                34          68.0            2216350.0             2484970.0
# 2                56          39.0              25475.0              147875.0
# 3               222           0.0                  0.0                   0.0
# 4               471          14.0                700.0                 700.0
# 5               531           0.0                  0.0                   0.0
# 6              1056           8.0                  0.0                   0.0
#
#    Total Valuechain Amount  Total InFlow Count  Total OutFlow Count  \
# 0                  18471.0                12.0                 15.0
# 1                 251088.0               126.0                143.0
# 2                  86505.0                15.0                 22.0
# 3                    510.0                 0.0                  0.0
# 4                  21898.0                 2.0                  2.0
# 5                1875247.0                 0.0                  0.0
# 6                    400.0                 0.0                  0.0
#
#    Total Valuechain Count  monthly_inflow_amount  monthly_outflow_amount  ...  \
# 0                    53.0                34340.0                 51340.0  ...
# 1                    80.0              1108175.0               1242485.0  ...
# 2                   193.0                12737.5                 73937.5  ...
# 3                     4.0                    0.0                     0.0  ...
# 4                   116.0                  700.0                   700.0  ...
# 5                  9995.0                    0.0                     0.0  ...
# 6                     2.0                    0.0                     0.0  ...
#
#    Average OutFlow  Value Chain    latest_product_used  latest_tran_date  \
# 0             15.0    26.500000          Prepaid Topup        2023-01-06
# 1             71.5    40.000000            Electricity        2023-01-06
# 2             11.0    96.500000            Electricity        2023-01-06
# 3              NaN     2.000000            Ncell Topup        2023-01-01
# 4              2.0    58.000000          Prepaid Topup        2023-01-06
# 5              NaN  3331.666667  TOPUP VIA BANK DIRECT        2023-03-29
# 6              NaN     2.000000          Prepaid Topup        2022-12-01
#
#   monthly_average_lifetime_revenue revenue_amount  product_usage  \
# 0                        20.430000          40.86             15
# 1                       258.215000         516.43             33
# 2                       101.055000         202.11             19
# 3                         1.910000           3.82              1
# 4                        49.890000          99.78              8
# 5                       758.013333        2274.04             88
# 6                        14.000000          14.00              2
#
#    most_used_product  second_most_used_product thirdmost_used_product
# 0   NT Prepaid Topup             Prepaid Topup             Send Money
# 1         Send Money               Electricity       NT Prepaid Topup
# 2        Ncell Topup               Electricity             Send Money
# 3        Ncell Topup                       NaN                    NaN
# 4        Ncell Topup          NT Prepaid Topup          Prepaid Topup
# 5  NT Topup via Bank      Ncell Topup via Bank  TOPUP VIA BANK DIRECT
# 6   NT Prepaid Topup             Prepaid Topup                    NaN
#
# [7 rows x 22 columns]
